# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import the pakeges

# %%
data = pd.read_csv("Dream.csv")
#load the data

# %%
data
# Out:
#     Unnamed: 0                                              Title  \
# 0            0  China's 30-year ROADMAP: Overtake USA and DOMI...
# 1            1  North Korea poses ‘VERY SERIOUS CHALLENGE to t...
# 2            2  World War 3 FEARS: China threatens to RETAKE T...
# 3            3  World War 3 FEARS: US could go to war with Chi...
# 4            4  China and Russia can keep GLOBAL PEACE, says X...
# 5            5  ‘We’ll TAKE BILLIONS off China’ - Trump issues...
# 6            6  ‘The US CANNOT make itself great again’ - Chin...
# 7            7  World War 3: How China could be key to solving...
# 8            8    China to build a permanent manned space station
# 9            9  US TRADE WAR: Trump to focus ‘ALL HIS IRE’ on ...
# 10          10                 Chinese space capsule lands safely
# 11          11  China becomes space exploration powerhouse as ...
# 12          12  Trump has a SECOND big red button on his desk ...
# 13          13  World War 3: China begins naval drills as Nort...
# 14          14  Corbyn is ‘DELUSIONAL’: Labour rounds on own l...
# 15          15  Melania Trump's sleepy home town cashing in on...
# 16          16  Chinese New Year: Will China remain top dog of...
# 17          17  Prince William is named a conservation hero fo...
# 18          18  The attack on the Grenfell Tower judge is drea...
# 19          19  London terror attack victims LATEST: Fourth vi...
# 20          20  DEADLIEST STAND-OFF: North Korea taunts Trump ...
#
#                                                   Url      Time  \
# 0   https://www.express.co.uk//news/world/868333/C...  20171019
# 1   https://www.express.co.uk//news/world/787548/n...  20170404
# 2   https://www.express.co.uk//news/world/1048669/...  20181122
# 3   https://www.express.co.uk//news/world/900593/w...  20180106
# 4   https://www.express.co.uk//news/world/804730/R...  20170515
# 5   https://www.express.co.uk//news/world/1126359/...  20190513
# 6   https://www.express.co.uk//news/world/977901/D...  20180622
# 7   https://www.express.co.uk//news/world/893030/W...  20171215
# 8   https://www.express.co.uk//news/world/797686/C...  20170428
# 9   https://www.express.co.uk//news/world/1025934/...  20181002
# 10  https://www.express.co.uk//news/world/410378/C...  20130626
# 11  https://www.express.co.uk//news/science/722147...  20161017
# 12  https://www.express.co.uk//news/world/797666/D...  20170428
# 13  https://www.express.co.uk//news/world/893029/W...  20171216
# 14  https://www.express.co.uk//news/politics/85903...  20170926
# 15  https://www.express.co.uk//life-style/style/78...  20170409
# 16  https://www.express.co.uk//finance/personalfin...  20180214
# 17  https://www.express.co.uk//news/nature/576696/...  20150512
# 18  https://www.express.co.uk//comment/columnists/...  20170709
# 19  https://www.express.co.uk//news/uk/782813/Lond...  20170324
# 20  https://www.express.co.uk//news/world/792421/n...  20170416
#
#                                               Content
# 0      Xi warned of “severe challenges” ahead but ...
# 1      After Donald Trump vowed to take on Pyongya...
# 2      Lieutenant General He Lei, former Vice Pres...
# 3     GETTYObservers believe China may by plotting...
# 4     GETTYVladimir Putin appears to be less than ...
# 5     Trump news: Trump increases tensions with Ch...
# 6      The Asian superstate’s official military ne...
# 7     GettyChina's approach could be the solution ...
# 8     GETTYChina will begin construction of a perm...
# 9     Donald Trump and Xi Jinping (Image: GETTY)Bu...
# 10                                               None
# 11     Two astronauts blasted off from the Jiuquan...
# 12    REUTERSThe US President is about to reach hi...
# 13    GettyChina has begun huge naval drills as No...
# 14     Mr Ummuna denounced as "ridiculous" the suc...
# 15    GETTYMelania Trump: A salami has been brough...
# 16    GETTYChina celebrated a runaway 12 months fo...
# 17    GETTYPrince William gets friendly with an el...
# 18    GETTYSir Martin Moore-Bick will head the inq...
# 19     The pensioner, from Streatham, was seriousl...
# 20     Kim Jong-un invited the world’s media to th...

# %%
import calendar

# %%
neg = {}
pos = {}
neu = {}

# %%
data['Time']
# Out:
# 0                 09:03, Thu, Oct 19, 2017
# 1                  01:39, Tue, Apr 4, 2017
# 2                 00:44, Thu, Nov 22, 2018
# 3      PUBLISHED:  08:30, Sat, Jan 6, 2018
# 4                 12:19, Mon, May 15, 2017
# 5                 05:20, Mon, May 13, 2019
# 6                 01:19, Fri, Jun 22, 2018
# 7                 22:00, Fri, Dec 15, 2017
# 8                 00:00, Fri, Apr 28, 2017
# 9                  20:36, Tue, Oct 2, 2018
# 10                07:18, Wed, Jun 26, 2013
# 11                17:56, Mon, Oct 17, 2016
# 12                08:02, Fri, Apr 28, 2017
# 13                07:51, Sat, Dec 16, 2017
# 14                00:01, Tue, Sep 26, 2017
# 15                 11:21, Sun, Apr 9, 2017
# 16                11:02, Wed, Feb 14, 2018
# 17                13:59, Tue, May 12, 2015
# 18                 13:23, Sun, Jul 9, 2017
# 19                00:00, Fri, Mar 24, 2017
# 20                00:01, Sun, Apr 16, 2017
# Name: Time, dtype: object

# %%
data['Time'][0].split()[-3]
#list(calendar.month_name).index(data['Time'][0].split()[-3])
timelist = list(calendar.month_name)
for i in range(len(timelist)):
    timelist[i] = timelist[i][0:3]

# %%
for i in range(len(data)):
    time = 0
    try:
        if data['Time'][i] != 'None':
            d1 = data['Time'][i].split()[-1]
            d2 = timelist.index(data['Time'][i].split()[-3])
            if int(d2) < 10:
                d2 = '0' + str(d2)
            d3 = data['Time'][i].split()[-2][:-1]
            if int(d3) < 10:
                d3 = '0' + str(d3)
            #print(d1,d2,d3)
            data['Time'][i] = int(d1 + str(d2) + str(d3))
    except BaseException:
        pass
# Out:
# /home/sunny/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

for i in range(len(data)):
    ss = sid.polarity_scores(data['Content'][i])
    T = data['Time'][i]
    if T != 'None':
        neg[str(T)] = ss['neg']
        pos[str(T)] = ss['pos']
        neu[str(T)] = ss['neu']
    else:
        neg[str(0)] = ss['neg']
        pos[str(0)] = ss['pos']
        neu[str(0)] = ss['neu']

# %%
pos = sorted(pos.items(), key = lambda k:k[0])
neg = sorted(neg.items(), key = lambda k:k[0])
neu = sorted(neu.items(), key = lambda k:k[0])

# %%
pos
# Out:
# [('20130626', 0.0),
#  ('20150512', 0.12),
#  ('20161017', 0.067),
#  ('20170324', 0.044),
#  ('20170404', 0.063),
#  ('20170409', 0.137),
#  ('20170416', 0.102),
#  ('20170428', 0.08),
#  ('20170515', 0.08),
#  ('20170709', 0.097),
#  ('20170926', 0.094),
#  ('20171019', 0.159),
#  ('20171215', 0.068),
#  ('20171216', 0.078),
#  ('20180106', 0.069),
#  ('20180214', 0.065),
#  ('20180622', 0.09),
#  ('20181002', 0.133),
#  ('20181122', 0.08),
#  ('20190513', 0.067)]

# %%
def Process(L):
    List = [[],[]]
    stime = int(L[0][0]) // 100 * 100
    ntime = stime + 100
    sum = 0
    count = 0
    for a in L:
        t = int(a[0])
        k = t//100 - stime//100
        if t >= ntime:
            List[0].append(stime/10000)
            List[1].append(sum/count)
            stime = stime + 100*k
            ntime = ntime + 100*k
            count = 0
            sum = 0
        if t >= stime and t <= ntime:
            sum = sum + a[1]
            count = count + 1
    l = {
    'index' : [],
    'time' : [],
    'value' : []
    }
    c = 0
    for i in range(len(List[0]) - 1):
        if List[0][i+1] - List[0][i] != 0.01 and int(List[0][i+1]) == int(List[0][i]):
            n = List[0][i+1]*100 - List[0][i]*100 - 1
            n = int(n)
            if n > 0:
                for j in range(n):
                    c = c + 1
                    l['index'].append(c + i)
                    l['time'].append(List[0][i] + 0.01*(j+1))
                    l['value'].append((List[1][i] + List[1][i+1])/2)
    for i in range(len(l['index'])):
        List[0].insert(l['index'][i],l['time'][i])
        List[1].insert(l['index'][i],l['value'][i])
    return List

# %%
Pos = Process(pos)
for i in range(len(Pos[0])):
    Pos[0][i] = str(Pos[0][i])
    if Pos[0][i][-2] == '.':
        Pos[0][i] = Pos[0][i] + '0'
    Pos[0][i] = Pos[0][i][2:]
    if Pos[0][i][-2] == '0':
        Pos[0][i] = Pos[0][i][:-2] + Pos[0][i][-1]

# %%
Pos[0][0]
# Out:
# '13.6'

# %%
Neg = Process(neg)
for i in range(len(Neg[0])):
    Neg[0][i] = str(Neg[0][i])
Neg[0][0]
# Out:
# '2013.06'

# %%
import matplotlib.pyplot as plt
import numpy as np

fig,ax = plt.subplots()
x1 = np.arange(0,len(Pos[0][0:]))
y1 = Pos[1][0:]
x2 = np.arange(0,len(Neg[0][0:]))
y2 = Neg[1][0:]

group_labels = Pos[0][0:]

plt.figure(figsize=(38, 22))
plt.plot(x1,y1,lw = 3)
plt.plot(x2,y2,lw = 3)
plt.legend(['Positive Line','Negtive Line'],fontsize = 'xx-large')
my_x_ticks = np.arange(0, len(Pos[0][0:]))
plt.xticks(my_x_ticks, group_labels, rotation=0)
plt.grid()
plt.title('The Curve of "Chinese dream" in express.co.uk',fontsize = 'xx-large')
plt.xlabel('Time since 2013.06',fontsize = 'xx-large')
plt.ylabel('The factors (0~1)',fontsize = 'xx-large')
plt.savefig('Dream.jpg')
plt.show()

# %%
group_labels
# Out:
# ['14.8',
#  '15.2',
#  '16.3',
#  '17.1',
#  '17.2',
#  '17.3',
#  '17.4',
#  '17.5',
#  '17.6',
#  '17.7',
#  '17.8',
#  '17.9',
#  '17.10',
#  '17.11',
#  '17.12',
#  '18.1',
#  '18.2',
#  '18.3',
#  '18.4',
#  '18.5',
#  '18.6',
#  '18.7',
#  '18.8',
#  '18.9',
#  '18.10',
#  '18.11',
#  '18.12',
#  '19.1',
#  '19.2',
#  '19.3',
#  '19.4']

# %%
posindex = np.sum(y1)/len(y1)

negindex = np.sum(y2)/len(y2)

posindex,negindex
# Out:
# (0.08889583333333333, 0.07627083333333333)
